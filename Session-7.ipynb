# %%
food = 75
tip = 0.2 * 75
tax = 0.08875 * food
total = food + tip + tax
bill=int(total)
print(f'your bill is = ${bill}')
# Out:
# your bill is = $96

# %% [markdown]
# FLOWCHART
#
# start
#
# food = 75
#
# tip = 0.2 * 75
#
# tax = 0.08875 * food
#
# total = food + tip + tax

# %%
def get_cost(food):
    tip = 0.2 * 75
    tax = 0.08875 * food
    total = food + tip + tax
    return int(total)

food =int(input('what is your food cost = $'))
print(f'your bill is = ${get_cost(food)}')
# Out:
# your bill is = $96

# %%
def get_cost(food):
    total = food + 0.08875 * food + 0.2 * 75
    return int(total)

lunch = get_cost(20)
print(lunch)
dinner = get_cost(50)
print(dinner)
# Out:
# 36
# 69

# %% [markdown]
# ![image.png](attachment:image.png)
